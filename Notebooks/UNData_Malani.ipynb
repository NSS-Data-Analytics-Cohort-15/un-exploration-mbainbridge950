# %%
    import pandas as pd   
    import numpy as np  
    import matplotlib.pyplot as plt 
    import seaborn as sns

# %%
###Question 4
gdp_df = pd.read_csv('../Data/gdp_percapita.csv')

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2023  1992.424394              NaN
# 1        Afghanistan  2022  1981.710168              NaN
# 2        Afghanistan  2021  2144.166570              NaN
# 3        Afghanistan  2020  2769.685745              NaN
# 4        Afghanistan  2019  2927.245144              NaN
# ...              ...   ...          ...              ...
# 8214        Zimbabwe  1994  3965.730986              NaN
# 8215        Zimbabwe  1993  3634.750494              NaN
# 8216        Zimbabwe  1992  3649.891947              NaN
# 8217        Zimbabwe  1991  4126.405247              NaN
# 8218        Zimbabwe  1990  4013.299059              NaN
#
# [8219 rows x 4 columns]

# %%
##Question 5
gdp_df.shape
# Out:
# (8219, 4)

# %% [markdown]
# There are 8219 rows and 4 columns

# %%
gdp_df.info
# Out:
# <bound method DataFrame.info of      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2023  1992.424394              NaN
# 1        Afghanistan  2022  1981.710168              NaN
# 2        Afghanistan  2021  2144.166570              NaN
# 3        Afghanistan  2020  2769.685745              NaN
# 4        Afghanistan  2019  2927.245144              NaN
# ...              ...   ...          ...              ...
# 8214        Zimbabwe  1994  3965.730986              NaN
# 8215        Zimbabwe  1993  3634.750494              NaN
# 8216        Zimbabwe  1992  3649.891947              NaN
# 8217        Zimbabwe  1991  4126.405247              NaN
# 8218        Zimbabwe  1990  4013.299059              NaN
#
# [8219 rows x 4 columns]>

# %% [markdown]
# Types of columns

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
# object, text, integer, float

# %%
##Question 6
gdp_df=gdp_df.drop(columns=['Value Footnotes'])

# %%
gdp_df.columns=['Country', 'Year', 'GDP_Per_Capita']

# %% [markdown]
# gdp_df.drop(columns=['VF'])

# %%
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2023     1992.424394
# 1  Afghanistan  2022     1981.710168
# 2  Afghanistan  2021     2144.166570
# 3  Afghanistan  2020     2769.685745
# 4  Afghanistan  2019     2927.245144

# %%
gdp_df.describe()
# Out:
#               Year  GDP_Per_Capita
# count  8219.000000     8219.000000
# mean   2006.672345    20270.976242
# std       9.782986    22532.004246
# min    1990.000000      510.822823
# 25%    1998.000000     4284.868430
# 50%    2007.000000    11916.457927
# 75%    2015.000000    28543.305542
# max    2023.000000   174339.077325

# %% [markdown]
# gdp_df.dropna()

# %%
count_of_years = gdp_df.groupby('Country')['Year'].count().reset_index()
count_of_years
# Out:
#                          Country  Year
# 0                    Afghanistan    24
# 1    Africa Eastern and Southern    34
# 2     Africa Western and Central    34
# 3                        Albania    34
# 4                        Algeria    34
# ..                           ...   ...
# 242               Virgin Islands    21
# 243           West Bank and Gaza    30
# 244                        World    34
# 245                       Zambia    34
# 246                     Zimbabwe    34
#
# [247 rows x 2 columns]

# %%
print(count_of_years)
# Out:
#                          Country  Year
# 0                    Afghanistan    24
# 1    Africa Eastern and Southern    34
# 2     Africa Western and Central    34
# 3                        Albania    34
# 4                        Algeria    34
# ..                           ...   ...
# 242               Virgin Islands    21
# 243           West Bank and Gaza    30
# 244                        World    34
# 245                       Zambia    34
# 246                     Zimbabwe    34
#
# [247 rows x 2 columns]

# %%
gdp_df.count()
# Out:
# Country           8219
# Year              8219
# GDP_Per_Capita    8219
# dtype: int64

# %%
gdp_df.value_counts('Year').reset_index()
# Out:
#     Year  count
# 0   2017    247
# 1   2016    247
# 2   2014    247
# 3   2013    247
# 4   2018    247
# 5   2019    247
# 6   2020    247
# 7   2021    247
# 8   2015    247
# 9   2012    246
# 10  2011    246
# 11  2022    246
# 12  2010    245
# 13  2009    245
# 14  2008    244
# 15  2007    242
# 16  2006    242
# 17  2002    241
# 18  2005    241
# 19  2004    241
# 20  2003    241
# 21  2001    240
# 22  2000    240
# 23  2023    240
# 24  1997    238
# 25  1998    238
# 26  1999    238
# 27  1995    236
# 28  1996    236
# 29  1994    235
# 30  1992    234
# 31  1991    234
# 32  1993    234
# 33  1990    233

# %%
##Question 7
gdp_df.value_counts('Country')
pd.set_option('display.max_rows', None)
print(gdp_df.value_counts('Country'))
# Out:
# Country
# Africa Eastern and Southern                           34
# Africa Western and Central                            34
# Albania                                               34
# Andorra                                               34
# Algeria                                               34
# Angola                                                34
# Antigua and Barbuda                                   34
# Bahrain                                               34
# Arab World                                            34
# Argentina                                             34
# Armenia                                               34
# Aruba                                                 34
# Australia                                             34
# Austria                                               34
# Azerbaijan                                            34
# Belgium                                               34
# ...

# %%
year_2020 = gdp_df[gdp_df['Year'] == 2020]
year_2020.head()
# Out:
#                          Country  Year  GDP_Per_Capita
# 3                    Afghanistan  2020     2769.685745
# 27   Africa Eastern and Southern  2020     3861.111238
# 61    Africa Western and Central  2020     4622.731427
# 95                       Albania  2020    14650.395929
# 129                      Algeria  2020    14194.155748

# %%
##Question 8 Histogram
#np.random.seed(42)
#x = np.random.normal(size=1000)

#plt.hist(x, density=True, bins=30)  # density=False would make counts
#plt.ylabel('Probability')
#plt.xlabel('Data');



sns.histplot(data=year_2020, x="GDP_Per_Capita", kde=True)

#sns.displot(data=year_2020, x="GDP_Per_Capita", kde=True)
# Out:
# <Axes: xlabel='GDP_Per_Capita', ylabel='Count'>

# %%
#Question 8 Density
sns.kdeplot(year_2020['GDP_Per_Capita'])
# Out:
# <Axes: xlabel='GDP_Per_Capita', ylabel='Density'>

# %%
#Question 8 Boxplot
sns.boxplot( x=year_2020["Year"], y=year_2020["GDP_Per_Capita"] )
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
#Question 8 Violin Plot
sns.violinplot(x=year_2020["Year"], y=year_2020["GDP_Per_Capita"])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
#Question 9

year_2020['GDP_Per_Capita'].median()
# Out:
# 15309.23598817024

# %%
# 10 A.

#import pandas as pd
        #df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
        #subset_column = df['A']

#gdp_decades = gdp_df({'Year': [1990, 2000, 2010, 2020]})
#subset_column = gdp_decades

decades=[1990,2000,2010,2020]
gdp_decades = gdp_df[gdp_df['Year'].isin(decades)]
gdp_decades

#gdp_decades = gdp_df[gdp_df['Year'].isin([1990, 2000, 2010, 2020])]
#gdp_decades

#gdp_decades = gdp_df[(gdp_df['Year'] == 1990 )| (gdp_df['Year'] ==200)] | (gdp_df['Year'] == 2010) | (gdp_df['Year'] == 2020)]
#gdp_decades
# Out:
#                                                 Country  Year  GDP_Per_Capita
# 3                                           Afghanistan  2020     2769.685745
# 13                                          Afghanistan  2010     2848.586061
# 23                                          Afghanistan  2000     1617.826475
# 27                          Africa Eastern and Southern  2020     3861.111238
# 37                          Africa Eastern and Southern  2010     3863.836012
# 47                          Africa Eastern and Southern  2000     3176.568655
# 57                          Africa Eastern and Southern  1990     3386.854480
# 61                           Africa Western and Central  2020     4622.731427
# 71                           Africa Western and Central  2010     4343.405839
# 81                           Africa Western and Central  2000     3139.324872
# 91                           Africa Western and Central  1990     3299.401375
# ...

# %%
#10 B

sns.boxplot( x=gdp_decades['Year'], y=gdp_decades["GDP_Per_Capita"] )
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
#10 C

sns.barplot( x=gdp_decades['Year'], y=gdp_decades["GDP_Per_Capita"] )
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
#10 D

sns.scatterplot( x=gdp_decades['Year'], y=gdp_decades["GDP_Per_Capita"] )
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
#10 E

sns.regplot(x=gdp_decades['Year'], y=gdp_decades["GDP_Per_Capita"])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# GDP increased over time with less outliers.

# %%
#11

#Which country was the first to have a GDP per capita greater than $100,000?

#gdp_decades['GDP_Per_Capita'].max() > 100000

#gdp_df


#countrymax.nsmallest(5,'Year')
#countrymax.min()

countrymaxgdp=gdp_df[gdp_df['GDP_Per_Capita']>100000]
countrymaxgdp
countrymaxgdp.min()
# Out:
# Country                 Bermuda
# Year                       1990
# GDP_Per_Capita    100310.446245
# dtype: object

# %%
gdp1990 = gdp_df.loc[gdp_df['Year'] == 1990]
gdp1990
# Out:
#                                                 Country  Year  GDP_Per_Capita
# 57                          Africa Eastern and Southern  1990     3386.854480
# 91                           Africa Western and Central  1990     3299.401375
# 125                                             Albania  1990     5327.747458
# 159                                             Algeria  1990    11728.545729
# 193                                             Andorra  1990    50036.300776
# 227                                              Angola  1990     7391.752354
# 261                                 Antigua and Barbuda  1990    21078.785547
# 295                                          Arab World  1990    11052.361170
# 329                                           Argentina  1990    17007.284432
# 363                                             Armenia  1990     6137.600458
# 397                                               Aruba  1990    34579.220640
# ...

# %%
gdp1990[gdp1990['GDP_Per_Capita']>100000]
# Out:
#                    Country  Year  GDP_Per_Capita
# 974                 Brunei  1990   118163.683198
# 7827  United Arab Emirates  1990   108057.042464

# %% [markdown]
# Months are not listed, so two-way tie for earliest above.

# %%
#Question 12.  Which country had the highest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
#maxgdp2020 = year_2020['GDP_Per_Capita'].max()

max_gdp_value_2020 = year_2020['GDP_Per_Capita'].max()
year_2020.loc[year_2020['GDP_Per_Capita'] == max_gdp_value_2020]

#gdp1990 = gdp_df.loc[gdp_df['Year'] == 1990]
max_country = gdp_df.loc[gdp_df['Country'] == 'Luxembourg']
#sns.regplot(x=gdp_decades['Year'], y=gdp_decades["GDP_Per_Capita"])
sns.scatterplot(x=gdp_decades['Year'], y=max_country['GDP_Per_Capita'])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
max_country.plot(kind = 'bar',
                 x = 'Year', 
                 y = 'GDP_Per_Capita',
                 figsize = (10,3));

# %% [markdown]
# Luxembourg

# %%
#Question 13   Which country had the lowest GDP per capita in 2020? 
#**Bonus question:** Is it true in general that coutries had a higher GDP per capita in 2020 than in 1990? Which countries had lower GDP per capita in 2020 than in 1990?

# %%
#max_gdp_value_2020 = year_2020['GDP_Per_Capita'].max()
#year_2020.loc[year_2020['GDP_Per_Capita'] == max_gdp_value_2020]

min_gdp_value_2020 = year_2020['GDP_Per_Capita'].min()
year_2020.loc[year_2020['GDP_Per_Capita'] == min_gdp_value_2020]

min_country = gdp_df.loc[gdp_df['Country'] == 'Burundi']

# %%
#Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
min_country.plot(kind = 'bar',
                 x = 'Year', 
                 y = 'GDP_Per_Capita',
                 figsize = (10,3));

# %%
#14 Read in the internet use dataset into a DataFrame named `internet_df`. 
#You will likely get errors when doing this. Check the arguments for the read_csv function to find ones that can help correct the errors (https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) 
#Once you are able to read it in, take per a look at the top and bottom few rows to make sure that it has been read in correctly. Also, check the datatypes of the columns.

internet_df = pd.read_csv('../Data/internet_use.csv', nrows=6083)

# %%
#15 Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'Internet_Users_Pct'.

# %%
internet_dfv2 = internet_df.drop(columns=['Value Footnotes'])

# %%
internet_dfv2.columns=[ 'Country', 'Year', 'Internet_Users_Pct']
internet_dfv2.head()
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2019               17.60
# 1  Afghanistan  2018               16.80
# 2  Afghanistan  2017               13.50
# 3  Afghanistan  2016               11.00
# 4  Afghanistan  2015                8.26

# %%
#16. Look at the number of observations in this dataset per year. What do you notice?

# %%
internet_peryear = internet_dfv2.groupby('Year')['Internet_Users_Pct'].mean()
internet_peryear
# Out:
# Year
# 1990     0.022270
# 1991     0.280305
# 1992     0.399037
# 1993     0.456738
# 1994     0.658381
# 1995     0.948402
# 1996     1.461103
# 1997     2.541564
# 1998     3.991141
# 1999     6.263342
# 2000     9.332385
# 2001    11.417745
# 2002    14.243337
# 2003    16.768456
# 2004    19.313163
# 2005    21.595883
# 2006    24.201932
# 2007    26.109284
# 2008    28.920791
# 2009    31.612991
# 2010    34.735194
# 2011    37.754652
# 2012    40.009718
# 2013    42.741366
# 2014    45.604925
# 2015    48.434528
# 2016    51.780022
# 2017    54.902815
# 2018    58.187510
# 2019    61.575323
# 2020    65.761124
# 2021    68.785103
# 2022    71.156324
# 2023    86.615755
# Name: Internet_Users_Pct, dtype: float64

# %%
internet_peryear.plot(kind = 'bar',
                      x = 'Year',
                      y = 'PCT',
                      figsize = (15,3));

# %%
#17. What is the first year to have a non-zero internet users percentage value? 
internet_peryear = internet_dfv2.groupby('Year')['Internet_Users_Pct'].min()
internet_peryear
# Out:
# Year
# 1990     0.00000
# 1991     0.00000
# 1992     0.00000
# 1993     0.00000
# 1994     0.00000
# 1995     0.00000
# 1996     0.00000
# 1997     0.00000
# 1998     0.00000
# 1999     0.00000
# 2000     0.00000
# 2001     0.00000
# 2002     0.00000
# 2003     0.00000
# 2004     0.00000
# 2005     0.00000
# 2006     0.00000
# 2007     0.00000
# 2008     0.00000
# 2009     0.00000
# 2010     0.00000
# 2011     0.00000
# 2012     0.00000
# 2013     0.90000
# 2014     0.99000
# 2015     1.08373
# 2016     1.17712
# 2017     2.00405
# 2018     4.00000
# 2019     6.10000
# 2020     7.40000
# 2021     9.64241
# 2022    11.27500
# 2023    44.50270
# Name: Internet_Users_Pct, dtype: float64

# %%
#internet_peryear.nmsallest(20, 'Internet_Uers_Pct')
#year1internet = internet_dfv2 ['Internet_Users_Pct'].max()
year1internet=internet_dfv2.loc[internet_dfv2['Internet_Users_Pct']>0]
year1internet['Year'].min()
# Out:
# 1990

# %%
#18. How does the distribution of internet users percent differ for 2000 and 2014?
internet_decades = [2000,2014]
internet_decades = internet_dfv2[internet_dfv2['Year'].isin(internet_decades)]
internet_decades
# Out:
#                                              Country  Year  Internet_Users_Pct
# 5                                        Afghanistan  2014            7.000000
# 28                                           Albania  2014           54.300000
# 42                                           Albania  2000            0.114097
# 57                                           Algeria  2014           29.500000
# 71                                           Algeria  2000            0.491706
# 87                                           Andorra  2014           86.100000
# 100                                          Andorra  2000           10.538800
# 114                                           Angola  2014           21.362300
# 128                                           Angola  2000            0.105046
# 136                                         Anguilla  2014           70.390000
# 150                                         Anguilla  2000           22.405400
# ...

# %%
sns.boxplot(x=internet_decades['Year'], y=internet_decades['Internet_Users_Pct'])
# Out:
# <Axes: xlabel='Year', ylabel='Internet_Users_Pct'>

# %%
#Internet users are more evenly distributed in 2014.  In 2000 there are far fewer users and more outliers.

# %%
#19. For how many countries was the percentage of internet users below 5% in 2014?
year2014 = internet_dfv2.loc[internet_dfv2['Year'] == 2014]
year2014
year2014[year2014['Internet_Users_Pct']<5].count()
# Out:
# Country               10
# Year                  10
# Internet_Users_Pct    10
# dtype: int64

# %%
#20. Merge the two DataFrames to one. Do this in a way that keeps **all rows** from each of the two DataFrames. 
#Call the new DataFrame `gdp_and_internet_use`. Look at the first and last few rows to confirm that it merged correctly.
#merged_df = pd.merge(df1, df2, on=['key1', 'key2'], how='inner')
gdp_and_internet_use = pd.merge(gdp_df, internet_dfv2, on=['Country', 'Year'], how='left')
gdp_and_internet_use
# Out:
#                                                 Country  Year  GDP_Per_Capita  \
# 0                                           Afghanistan  2023     1992.424394
# 1                                           Afghanistan  2022     1981.710168
# 2                                           Afghanistan  2021     2144.166570
# 3                                           Afghanistan  2020     2769.685745
# 4                                           Afghanistan  2019     2927.245144
# 5                                           Afghanistan  2018     2902.392113
# 6                                           Afghanistan  2017     2952.998916
# 7                                           Afghanistan  2016     2958.785399
# 8                                           Afghanistan  2015     2967.692067
# 9                                           Afghanistan  2014     3017.942544
# 10                                          Afghanistan  2013     3046.579931
# ...

# %%
#21 Find the three countries with the highest internet users percentage in 2014. 
#Use a seaborn FacetGrid (https://seaborn.pydata.org/generated/seaborn.FacetGrid.html) to compare how the GDP per capita has changed over time for these three countries. 
#What do you notice?
